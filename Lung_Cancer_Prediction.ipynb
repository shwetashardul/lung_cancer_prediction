# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # EDA

# %%
# Replace 'data.csv' with the path to your dataset
url = 'https://drive.google.com/file/d/1QHwr0ikco84Gihc59ie3slOrMzy-dwPJ/view?usp=share_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
df.describe()
# Out:
#              index          Age       Gender  Air Pollution  Alcohol use  \
# count  1000.000000  1000.000000  1000.000000      1000.0000  1000.000000
# mean    499.500000    37.174000     1.402000         3.8400     4.563000
# std     288.819436    12.005493     0.490547         2.0304     2.620477
# min       0.000000    14.000000     1.000000         1.0000     1.000000
# 25%     249.750000    27.750000     1.000000         2.0000     2.000000
# 50%     499.500000    36.000000     1.000000         3.0000     5.000000
# 75%     749.250000    45.000000     2.000000         6.0000     7.000000
# max     999.000000    73.000000     2.000000         8.0000     8.000000
#
#        Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count   1000.000000           1000.000000   1000.000000           1000.000000
# mean       5.165000              4.840000      4.580000              4.380000
# ...

# %%
df.isnull().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
df['Level'].value_counts()
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %% [markdown]
# # Visualizations

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()
#correlation_matrix = df.corr()

# Set the figure size
plt.figure(figsize=(14, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, linewidths=.5)

# Improve readability by rotating x-axis labels
plt.xticks(rotation=45, ha='right')

# Title for the heatmap
plt.title('Correlation Heatmap of Lung Cancer Dataset')

plt.savefig('correlation_heatmap.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of seaborn
sns.set(style="whitegrid")

# Set the size of the figure
plt.figure(figsize=(12, 8))

# Create subplots for each feature
for i, feature in enumerate(['Alcohol use', 'Obesity', 'Passive Smoker', 'Coughing of Blood']):
    data=df[feature].value_counts().sort_index()
    labels=data.index
    sizes=data.values.astype(int)
    plt.subplot(2, 2, i + 1)
    plt.pie(sizes, labels=labels, autopct='%d%%', startangle=90,textprops={'fontsize': 8})
    plt.xlabel(feature)
    #plt.ylabel()

# Adjust layout
plt.tight_layout()

plt.savefig('pie_charts.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of seaborn
sns.set(style="whitegrid")

# Set the size of the figure
plt.figure(figsize=(12, 8))

# Create subplots for each feature
for i, feature in enumerate(['Alcohol use', 'Obesity', 'Passive Smoker', 'Coughing of Blood']):
    plt.subplot(2, 2, i + 1)
    sns.countplot(x=feature,hue='Level',data=df)
    #plt.title(f'{feature} Bar Chart')
    plt.xlabel(feature)
    #plt.ylabel()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Encoding

# %%
# Define the order of the categories
levels = ['Low', 'Medium', 'High']

# Create a dictionary to map categories to numerical values
level_mapping = {size: index for index, size in enumerate(levels)}

# Apply the ordinal encoding to the 'Size' column
df['Level_encoded'] = df['Level'].map(level_mapping)

# %%
level_mapping
# Out:
# {'Low': 0, 'Medium': 1, 'High': 2}

# %% [markdown]
# ## Feature Selection

# %%
cols=np.array(['Age', 'Gender', 'Air Pollution', 'Alcohol use', 'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking', 'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath', 'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold', 'Dry Cough', 'Snoring'])
temp_X=df[cols]
temp_y=df['Level']

# %%
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2


# Create SelectKBest instance with chi-square as the score function
k_best = SelectKBest(score_func=chi2, k=4)

# Fit and transform the features using SelectKBest
X_k_best = k_best.fit_transform(temp_X, temp_y)

# Get the indices of the selected features
selected_features_indices = k_best.get_support(indices=True)

# Print the selected features
tr_cols=cols[selected_features_indices]
tr_cols
# Out:
# array(['Alcohol use', 'Obesity', 'Passive Smoker', 'Coughing of Blood'],
#       dtype='<U24')

# %%
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif


# Create SelectKBest instance with chi-square as the score function
k_best = SelectKBest(score_func=mutual_info_classif, k=4)

# Fit and transform the features using SelectKBest
X_k_best = k_best.fit_transform(temp_X, temp_y)

# Get the indices of the selected features
selected_features_indices = k_best.get_support(indices=True)

# Print the selected features
tr_cols=cols[selected_features_indices]
tr_cols
# Out:
# array(['Alcohol use', 'Obesity', 'Passive Smoker', 'Coughing of Blood'],
#       dtype='<U24')

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Split the Data

# %%
from sklearn.model_selection import train_test_split
# Define the percentage of data to be used for testing (e.g., 20% for testing)
test_size = 0.2
X=df[tr_cols]
y=df['Level_encoded']
# Set a random seed for reproducibility (optional but recommended)
random_seed = 42

# Perform the train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_seed)

# %% [markdown]
# ## Building the models

# %%
from sklearn.svm import SVC

svm_classifier = SVC(kernel='linear', C=1.0)

# Train the SVM classifier on the training data
svm_classifier.fit(X_train, y_train)
# Get the hyperplane parameters
w = np.round(svm_classifier.coef_[0],2)
b = np.round(svm_classifier.intercept_[0],2)
print(w,b)
# Out:
# [-0.06 -0.85 -0.02 -0.38] 4.07

# %%
from sklearn.tree import DecisionTreeClassifier
# Create a Decision Tree classifier
dt_clf = DecisionTreeClassifier(max_depth=5)

# Train the Decision Tree classifier on the training data
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
import dtreeviz

# Assuming dt_clf is your trained decision tree classifier
# and X_train, y_train are your training dataset and labels
viz = dtreeviz(dt_clf, X_train, y_train,
               target_name="target",
               feature_names=X_train.columns,
               class_names=["Class 0", "Class 1", "Class 2"])  # Adjust class_names as per your dataset

# Save the visualization to a file
viz.save("decision_tree.svg")

# Display the visualization in Jupyter (optional)
viz.view()
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(dt_clf, feature_names=X_train.columns, class_names=["Class 0", "Class 1", "Class 2"], filled=True)
plt.savefig('decision_tree_plot.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from dtreeviz.trees import dtreeviz
#       3 # Assuming dt_clf is your trained decision tree classifier
#       4 # and X_train, y_train are your training dataset and labels
#       5 viz = dtreeviz(dt_clf, X_train, y_train,
#       6                target_name="target",
#       7                feature_names=X_train.columns,
#       8                class_names=["Class 0", "Class 1", "Class 2"])  # Adjust class_names as per your dataset
#
# ImportError: cannot import name 'dtreeviz' from 'dtreeviz.trees' (c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\dtreeviz\trees.py)

# %%
from sklearn.linear_model import LogisticRegression
# Create a logistic regression model
lr_clf = LogisticRegression()

# Train the model on the training data
lr_clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## SVM

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Make predictions on the test data
y_pred = svm_classifier.predict(X_test)

# Assuming you have true labels and predicted labels
true_labels = y_test
predicted_labels = y_pred

# Generate confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix using seaborn and matplotlib
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1", "Class 2"], yticklabels=["Class 0", "Class 1", "Class 2"])
plt.title("Confusion Matrix: SVM")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")


# Save the figure to a file before showing it
plt.savefig('confusion_matrix_svm.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
# Evaluate the classifier's performance (e.g., using accuracy)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate the F1 score
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' accounts for class imbalance
print("F1 Score:", f1)
# Out:
# Accuracy: 0.92
# F1 Score: 0.9199165947656024

# %% [markdown]
# ## Decision Tree

# %%
# Make predictions on the test data
y_pred = dt_clf.predict(X_test)

# Assuming you have true labels and predicted labels
true_labels = y_test
predicted_labels = y_pred

# Generate confusion matrix
cm2 = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix using seaborn and matplotlib
plt.figure(figsize=(8, 6))
sns.heatmap(cm2, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1", "Class 2"], yticklabels=["Class 0", "Class 1", "Class 2"])
plt.title("Confusion Matrix: Decision Tree")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")

# Save the figure to a file before showing it
plt.savefig('confusion_matrix_Decision_Tree.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
cm2
# Out:
# array([[55,  0,  0],
#        [ 0, 63,  0],
#        [ 0,  0, 82]])

# %%
# Evaluate the classifier's performance (e.g., using accuracy)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate the F1 score
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' accounts for class imbalance
print("F1 Score:", f1)
# Out:
# Accuracy: 1.0
# F1 Score: 1.0

# %% [markdown]
# ## Logistic Regression

# %%
# Make predictions on the test data
y_pred = lr_clf.predict(X_test)

# Assuming you have true labels and predicted labels
true_labels = y_test
predicted_labels = y_pred

# Generate confusion matrix
cm3 = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix using seaborn and matplotlib
plt.figure(figsize=(8, 6))
sns.heatmap(cm3, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1", "Class 2"], yticklabels=["Class 0", "Class 1", "Class 2"])
plt.title("Confusion Matrix: Logistic Regression")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")

# Save the figure to a file before showing it
plt.savefig('confusion_matrix_LR.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
cm3
# Out:
# array([[46,  9,  0],
#        [16, 46,  1],
#        [ 0,  1, 81]])

# %%
# Evaluate the classifier's performance (e.g., using accuracy)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate the F1 score
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' accounts for class imbalance
print("F1 Score:", f1)
# Out:
# Accuracy: 0.865
# F1 Score: 0.8647687280040222
